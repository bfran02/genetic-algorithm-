# %% [markdown]
# # PORTAFOLIO DE INVERSIÓN

# %% [markdown]
# **Centro Universitario UAEM Atlacomulco**
#
# **Alumna:** Berenice Francisco Jiménez
#
# **Catedrático:** Dr. Juan Fernando García Mejía
#
# **Unidad de Aprendizaje:** Sistemas Expertos - ICO23

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import math

# %% [markdown]
# Se muestran los activos correspondientes a los meses del último año de las empresas:
# 1. Hyundai
# 2. Honda
# 3. General Motors
# 4. Volkswagen
# 5. Ford
# 6. Tesla
# 7. Mazda
# 8. BMW
# 9. Toyota
# 10. Volvo

# %%
df=pd.read_csv('activos.csv') 
df
# Out:
#    Empresas-Periodo  Hyundai   Honda  General Motors  Volkswagen    Ford  \
# 0            mar-22   691.30  630.00          251.60     3488.50  344.99
# 1            feb-22   779.08  620.00          314.90     4334.24  424.45
# 2            ene-22   794.45  632.00          369.98     4397.02  446.87
# 3            dic-21   754.94  605.23          352.43     4250.00  421.23
# 4            nov-21   765.92  630.00          333.98     4690.00  370.94
# 5            oct-21   761.53  611.33          303.91     4570.23  290.00
# 6            sep-21   805.42  637.55          271.75     4803.00  261.89
# 7            ago-21   866.87  655.00          311.07     4803.37  276.34
# 8            jul-21   943.68  645.00          317.63     5050.00  299.00
# 9            jun-21   899.79  650.00          326.91     5706.49  295.57
# 10           may-21   877.84  615.72          331.22     4992.51  234.58
# 11           abr-21   862.48  600.00          346.13     5850.00  258.50
#
# ...

# %% [markdown]
# Se realiza el calculo correspodiente al rendimiento en base a:
#
#    $$(r_i-r_f)/r_f$$
# Se muestra en la siguiente tabla

# %%
def rendimiento(): #Rendimiento del portafolio de inversión
    activos=df.to_numpy(copy=True)
    a, r, rp, ri = [], 0, [], []
    for i in range(11):
        b=[]
        for j in range(1, 11): b.append((activos[i][j]-activos[i+1][j])/activos[i+1][j]) #mes actual - mes anterior/mes anterior
        a.append(b)
    return a #Tabla de rendimientos

rendimientos= rendimiento()
covarianza = np.cov(rendimientos, rowvar=False) #tabla de covarianzas
print("RENDIMIENTOS")
r = pd.DataFrame(rendimientos)
r
# Out:
# RENDIMIENTOS
#            0         1         2         3         4         5         6  \
# 0  -0.112671  0.016129 -0.201016 -0.195130 -0.187207 -0.070363 -0.040958
# 1  -0.019347 -0.018987 -0.148873 -0.014278 -0.050171 -0.219903  0.011812
# 2   0.052335  0.044231  0.049797  0.034593  0.060869  0.036735 -0.041160
# 3  -0.014336 -0.039317  0.055243 -0.093817  0.135574 -0.051671 -0.096321
# 4   0.005765  0.030540  0.098944  0.026207  0.279103  0.573578  0.076018
# 5  -0.054493 -0.041126  0.118344 -0.048463  0.107335  0.079997 -0.025570
# 6  -0.070887 -0.026641 -0.126402 -0.000077 -0.052291  0.041350 -0.053511
# 7  -0.081394  0.015504 -0.020653 -0.048838 -0.075786  0.040352  0.012279
# 8   0.048778 -0.007692 -0.028387 -0.115043  0.011605  0.087814  0.090670
# 9   0.025005  0.055675 -0.013012  0.143010  0.259997 -0.097749  0.121443
# 10  0.017809  0.026200 -0.043076 -0.146579 -0.092534 -0.021667 -0.071710
#
#            7         8         9
# 0  -0.137065 -0.086706 -0.143069
# ...

# %%
print("MATRIZ DE COVARIANZA")
covar=pd.DataFrame(covarianza)
covar
# Out:
# MATRIZ DE COVARIANZA
#           0         1         2         3         4         5         6  \
# 0  0.003023  0.000696  0.002484  0.001907  0.004169  0.001640  0.001411
# 1  0.000696  0.001127  0.000047  0.001166  0.000962  0.001179  0.001034
# 2  0.002484  0.000047  0.010503  0.003269  0.011373  0.011511  0.000864
# 3  0.001907  0.001166  0.003269  0.008977  0.009838  0.002787  0.003481
# 4  0.004169  0.000962  0.011373  0.009838  0.021955  0.014614  0.005173
# 5  0.001640  0.001179  0.011511  0.002787  0.014614  0.039936  0.004185
# 6  0.001411  0.001034  0.000864  0.003481  0.005173  0.004185  0.005032
# 7  0.001479  0.000107  0.005917  0.004639  0.010137  0.003416  0.000939
# 8  0.002222  0.001306  0.003915  0.004931  0.007343  0.001943  0.002296
# 9  0.002909 -0.001665  0.010004 -0.002500  0.005825  0.003866 -0.003680
#
#           7         8         9
# 0  0.001479  0.002222  0.002909
# 1  0.000107  0.001306 -0.001665
# 2  0.005917  0.003915  0.010004
# ...

# %% [markdown]
# El retorno del activo financiero(rendimiento promedio) se obtiene mediante la ecuación:
# $$∑_(n=1) r_n*W_n $$
#
# El riesgo del portafolio se obtiene mediante:
# $$∑_(n=1)∑_(m=1) W_n*W_m*σ_nm $$

# %%
def rendimientoPActivo(): #Rendimientos por activos
    rp = []
    global rendimientos
    for j in range(10):
        r=0
        for i in range(11): r+=rendimientos[i][j] #Suma de los rendimientos
        rp.append(r/11)
    return rp #Rendimiento promedio 

def rendP(w): #Rendimiento del portafolio 
    rn, rp =rendimientoPActivo(), 0
    for n in range(10): rp += (rn[n]*w[n])
    return rp
    
def riesgoP(w): #Riesgo del portafolio
    global covarianza
    re = 0
    for n in range(10):
        for m in range(10): re += (w[n]*w[m]*covarianza[n][m])
    return re

def fobj(w): #Funcion objetivo
    rendimiento, riesgo = rendP(w), riesgoP(w)
    return rendimiento/riesgo 

def restriccion(w): #La suma de los montos a invertir es 1
    suma = sum(w)
    for i in range(10): w[i]=(w[i]/suma)
    return w

def cromosoma(): #Se generan 10 montos a invertir 
    w=[random.random() for i in range(10)]
    return restriccion(w)

def crearPoblacion(): 
    return [cromosoma() for i in range(100)]

# %% [markdown]
# # POBLACIÓN INICIAL

# %%
poblacion = crearPoblacion()
fitness = []
x=pd.DataFrame(poblacion)
x
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.159409  0.111989  0.007359  0.136924  0.168993  0.169738  0.086123
# 1   0.144726  0.134163  0.017863  0.024928  0.158766  0.072983  0.071507
# 2   0.041942  0.036367  0.031521  0.181543  0.032776  0.190135  0.034037
# 3   0.007769  0.215575  0.091240  0.019905  0.142726  0.017342  0.163753
# 4   0.105585  0.032049  0.136187  0.149987  0.047912  0.055443  0.159551
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.048725  0.086041  0.246228  0.057682  0.094829  0.032549  0.039389
# 96  0.114287  0.154970  0.129017  0.011476  0.083181  0.065274  0.134892
# 97  0.163378  0.137446  0.020393  0.059491  0.061947  0.104536  0.098563
# 98  0.026603  0.022058  0.100970  0.104898  0.175957  0.202678  0.025341
# 99  0.065588  0.113820  0.096913  0.128280  0.046588  0.005013  0.117110
#
#            7         8         9
# 0   0.054478  0.075855  0.029131
# ...

# %%
def calcularFitness(): #Evaluación de la funcion objetivo 
    global poblacion, fitness
    fitness = []
    for cromosoma in poblacion:
        fitness.append(fobj(cromosoma))

def ordenar(): #Ordena los cromosomas de acuerdo a su aptitud 
    global poblacion, fitness
    ordenados = sorted(zip(fitness, poblacion), key = lambda x: x[0], reverse = True)
    poblacion = [cromosoma[1] for cromosoma in ordenados]
    fitness = [j[0] for j in ordenados]

def torneo(): #Método de selección 
    global poblacion
    h1, h2, h3 = random.randint(0, (len(poblacion)-1)), random.randint(0, (len(poblacion)-1)), random.randint(0, (len(poblacion)-1))
    t = sorted([h1, h2, h3])
    selected = [poblacion[i] for i in t] #ordena los mejores 3
    return selected[0], selected[1] #devuelve los mejores 2

def seleccionCruza(): 
    hijos = [] 
    global poblacion, fitness
    calcularFitness()
    ordenar()
    for i in range(40): #80% de la poblacion se cruza
        c1, c2 = torneo()
        alpha = random.random()
        h1 = [(c1[j]*(1 - alpha)+(c2[j]*alpha)) for j in range(10)] #Cruza aritmética
        h2 = [(c2[j] * (1 - alpha) + (c1[j] * alpha)) for j in range(10)]
        hijos.append(restriccion(h1)) #Verificar la restricción del portafolio 
        hijos.append(restriccion(h2))
    return hijos

def mutacion(hijos): #Se muta entre el 1% y el 5%
    porcentaje = random.randint(1, 4) #Porcentaje de mutación
    for i in range(porcentaje):
        cMutar, gMutar = random.randint(0, (len(hijos)-1)), random.randint(0, 9)
        genNuevo = random.random() #Mutación Uniforme
        while (genNuevo == hijos[cMutar][gMutar]): #Verifica que no sea el mismo gen que se va a mutar
            genNuevo = random.random()
        hijos[cMutar][gMutar] = genNuevo
        hijos[cMutar]=restriccion(hijos[cMutar])
    return hijos

def reemplazo(hijos): #Se reemplazan el 80% de la peor población 
    global poblacion
    j = 0
    for i in range(40, 100): 
        poblacion[i] = hijos[j]
        j += 1

# %% [markdown]
# # POBLACIÓN FINAL

# %%
historialEvolucion = [] #Guarda el mejor resultado de las iteraciones 
for i in range(1000):
    hijos = seleccionCruza()
    mutacion(hijos)
    reemplazo(hijos)
    calcularFitness()
    ordenar()
    historialEvolucion.append(fitness[0])
y=pd.DataFrame(poblacion)
y
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.002285  0.688102  0.004052  0.000385  0.019751  0.047745  0.000623
# 1   0.002286  0.688408  0.004054  0.000386  0.019760  0.047753  0.000623
# 2   0.002286  0.688528  0.004055  0.000386  0.019764  0.047744  0.000624
# 3   0.002286  0.688613  0.004055  0.000386  0.019766  0.047743  0.000624
# 4   0.002288  0.689167  0.004059  0.000386  0.019782  0.047752  0.000624
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.002298  0.692021  0.004075  0.000388  0.019864  0.047837  0.000627
# 96  0.002023  0.609257  0.003588  0.000341  0.135768  0.042086  0.000552
# 97  0.002011  0.605650  0.003567  0.000339  0.140933  0.041834  0.000548
# 98  0.001781  0.536354  0.003159  0.000300  0.015396  0.037005  0.000486
# 99  0.001564  0.470977  0.002774  0.000264  0.013519  0.032504  0.000427
#
#            7         8         9
# 0   0.001623  0.222375  0.013059
# ...

# %%
plt.plot([x for x in range(len(historialEvolucion))], historialEvolucion)
plt.show()

# %% [markdown]
# # MEJOR RESULTADO

# %%
empresas = ['HYUNDAI', 'HONDA', 'GM', 'VOLSKWAGEN', 'FORD', 'TESLA', 'MAZDA', 'BMW', 'TOYOTA', 'VOLVO']
x=pd.DataFrame(poblacion[0],empresas)
x
# Out:
#                    0
# HYUNDAI     0.002285
# HONDA       0.688102
# GM          0.004052
# VOLSKWAGEN  0.000385
# FORD        0.019751
# TESLA       0.047745
# MAZDA       0.000623
# BMW         0.001623
# TOYOTA      0.222375
# VOLVO       0.013059

# %%
rend=rendP(poblacion[0])
ries=riesgoP(poblacion[0])
plt.bar(['RENDIMIENTO', 'RIESGO'], [rend, ries], color=['green','blue'], alpha=0.3)
plt.title('GRÁFICA DE RIESGO Y RENDIMIENTO FINAL')
plt.show()
print("Rendimiento: ", rend)
print("Riesgo: ", ries)
# Out:
# Rendimiento:  0.009722896073766123
# Riesgo:  0.0015118746346606314

# %%
plt.pie(poblacion[0], labels=empresas)
plt.title('PORTAFOLIO DE INVERSIÓN')
plt.show()
r=pd.DataFrame(poblacion[0],empresas)
r
# Out:
#                    0
# HYUNDAI     0.002285
# HONDA       0.688102
# GM          0.004052
# VOLSKWAGEN  0.000385
# FORD        0.019751
# TESLA       0.047745
# MAZDA       0.000623
# BMW         0.001623
# TOYOTA      0.222375
# VOLVO       0.013059

# %% [markdown]
# # Conclusiones

# %% [markdown]
# Al término del algoritmo genético, se concluyo que el uso de algoritmos evolutivos, para este caso un algoritmo genético canónico, se muestra mejores resultados en cuanto a rendimiento y riesgo en las inversiones de un portfolio de inversión, tambien se nota que para todos los activos se les asigna un monto de inversión, de esta forma tambien se reduce el riesgo de perdidas, comparado con otros métodos clásicos como el uso de GRG (Gradiente Reducido Generalizado), donde se obsevaba que solo se invertia en algunos activos, y que en cuanto a resultados el nivel de riesgo es mucho mayor.
